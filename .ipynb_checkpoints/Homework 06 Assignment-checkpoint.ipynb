# %% [markdown]
# ## Author: Birju Dhaduk
# ## Date: 20200330
# ## CS301-006, Professor Watson
# ## HW06 Solution
#
# The purpose of this assignment is to help students practice using Python to prepare their data sets for machine learning.
#
# link to the git repo:https://github.com/birjudhaduk/cs301

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Question 1 - Read in the data set and print the % empty values for each column. Are there any columns with missing values?

# %%
df = pd.read_csv('C:\\Users\\birju\\Documents\\CS 301\\groundhog.csv')
df
# Out:
#      Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 0             0  1886         No Record                           NaN
# 1             1  1887       Full Shadow                           NaN
# 2             2  1888       Full Shadow                           NaN
# 3             3  1889         No Record                           NaN
# 4             4  1890         No Shadow                           NaN
# ..          ...   ...               ...                           ...
# 126         126  2012       Full Shadow                         37.51
# 127         127  2013         No Shadow                         34.77
# 128         128  2014       Full Shadow                         32.13
# 129         129  2015       Full Shadow                         32.99
# 130         130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      47.7
# 127                                      33.9
# 128                                      30.3
# 129                                      31.6
# 130                                      43.4
#
# [131 rows x 11 columns]

# %%
def  get_percent_nans(df, column_name):
    colSize = df.shape[0]
    empty = df.loc[df[column_name].isna()]
    emptySize = empty.shape[0]
    return (emptySize/colSize) * 100

# %%
for col in df.columns:
    print('The \"{}\" column has {:.2f}% empty values'.format(col, get_percent_nans(df, col)))
# Out:
# The "Unnamed: 0" column has 0.00% empty values
# The "Year" column has 0.00% empty values
# The "Punxsutawney Phil" column has 0.00% empty values
# The "February Average Temperature" column has 6.87% empty values
# The "February Average Temperature (Northeast)" column has 6.87% empty values
# The "February Average Temperature (Midwest)" column has 6.87% empty values
# The "February Average Temperature (Pennsylvania)" column has 6.87% empty values
# The "March Average Temperature" column has 6.87% empty values
# The "March Average Temperature (Northeast)" column has 6.87% empty values
# The "March Average Temperature (Midwest)" column has 6.87% empty values
# The "March Average Temperature (Pennsylvania)" column has 6.87% empty values

# %% [markdown]
# There are 8 columns with 9 (6.87%) missing values in each corresponding to the same 9 rows

# %% [markdown]
# #### Question 2 - Create a new dataframe which is a copy of the orginal one. In this copy, replace the missing values in the data set using one of the discussed methods in class.

# %%
cp_df = df.copy()
columns = ['February Average Temperature', 'February Average Temperature (Northeast)', 'February Average Temperature (Midwest)', 'February Average Temperature (Pennsylvania)', 'March Average Temperature', 'March Average Temperature (Northeast)', 'March Average Temperature (Midwest)', 'March Average Temperature (Pennsylvania)']
for col in columns:
    for i in range(0,9):
        if cp_df.loc[i, 'Punxsutawney Phil'] == 'No Record':
            cp_df.loc[i, col] = (cp_df.loc[(cp_df['Punxsutawney Phil'] == 'No Record')])[col].median()
        if cp_df.loc[i, 'Punxsutawney Phil'] == 'No Shadow':
            cp_df.loc[i, col] = (cp_df.loc[(cp_df['Punxsutawney Phil'] == 'No Shadow')])[col].median()
        if cp_df.loc[i, 'Punxsutawney Phil'] == 'Partial Shadow':
            cp_df.loc[i, col] = (cp_df.loc[(cp_df['Punxsutawney Phil'] == 'Partial Shadow')])[col].median()
        if cp_df.loc[i, 'Punxsutawney Phil'] == 'Full Shadow':
            cp_df.loc[i, col] = (cp_df.loc[(cp_df['Punxsutawney Phil'] == 'Full Shadow')])[col].median()

# %%
for col in cp_df.columns:
    print('The \"{}\" column has {:.2f}% empty values'.format(col, get_percent_nans(cp_df, col)))
# Out:
# The "Unnamed: 0" column has 0.00% empty values
# The "Year" column has 0.00% empty values
# The "Punxsutawney Phil" column has 0.00% empty values
# The "February Average Temperature" column has 0.00% empty values
# The "February Average Temperature (Northeast)" column has 0.00% empty values
# The "February Average Temperature (Midwest)" column has 0.00% empty values
# The "February Average Temperature (Pennsylvania)" column has 0.00% empty values
# The "March Average Temperature" column has 0.00% empty values
# The "March Average Temperature (Northeast)" column has 0.00% empty values
# The "March Average Temperature (Midwest)" column has 0.00% empty values
# The "March Average Temperature (Pennsylvania)" column has 0.00% empty values

# %%
cp_df
# Out:
#      Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 0             0  1886         No Record                        32.425
# 1             1  1887       Full Shadow                        33.575
# 2             2  1888       Full Shadow                        33.575
# 3             3  1889         No Record                        32.425
# 4             4  1890         No Shadow                        35.550
# ..          ...   ...               ...                           ...
# 126         126  2012       Full Shadow                        37.510
# 127         127  2013         No Shadow                        34.770
# 128         128  2014       Full Shadow                        32.130
# 129         129  2015       Full Shadow                        32.990
# 130         130  2016         No Shadow                        39.470
#
#      February Average Temperature (Northeast)  \
# 0                                       21.15
# 1                                       22.95
# 2                                       22.95
# 3                                       21.15
# 4                                       24.10
# ..                                        ...
# 126                                     30.60
# 127                                     25.30
# 128                                     21.00
# 129                                     12.10
# 130                                     28.10
#
#      February Average Temperature (Midwest)  \
# 0                                     28.55
# 1                                     32.95
# 2                                     32.95
# 3                                     28.55
# 4                                     34.30
# ..                                      ...
# 126                                   38.60
# 127                                   33.40
# 128                                   27.10
# 129                                   23.40
# 130                                   36.90
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                          23.80                     38.645
# 1                                          26.95                     41.810
# 2                                          26.95                     41.810
# 3                                          23.80                     38.645
# 4                                          27.40                     42.800
# ..                                           ...                        ...
# 126                                        34.30                     50.410
# 127                                        27.40                     40.910
# 128                                        22.80                     40.510
# 129                                        16.10                     45.390
# 130                                        30.80                     47.500
#
#      March Average Temperature (Northeast)  \
# 0                                     29.9
# 1                                     32.4
# 2                                     32.4
# 3                                     29.9
# 4                                     33.0
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 0                                  39.35
# 1                                  42.70
# 2                                  42.70
# 3                                  39.35
# 4                                  43.50
# ..                                   ...
# 126                                56.30
# 127                                37.30
# 128                                38.00
# 129                                41.60
# 130                                49.50
#
#      March Average Temperature (Pennsylvania)
# 0                                       34.35
# 1                                       35.60
# 2                                       35.60
# 3                                       34.35
# 4                                       37.20
# ..                                        ...
# 126                                     47.70
# 127                                     33.90
# 128                                     30.30
# 129                                     31.60
# 130                                     43.40
#
# [131 rows x 11 columns]

# %% [markdown]
# #### Question 3 - Is your proposed method from Question 2 appropriate in this case? Why or why not?

# %% [markdown]
# The method I used in Question 2 is replacing the empty values with the median value of each respective column from the rows that have the same value in the 'Punxsutawney Phil' column.

# %% [markdown]
# Although this is the best that could be done given the information given, this method is not appropriate as the rows that have "No Record" could actually be any of the other 3 options but we can not know which one and thus making predictions for those rows is not appropriate. It also does not make sense to make predictions for 8 rows when there are only values given in 3 of the rows.

# %% [markdown]
# #### Question 4 - Using the original dataframe (unchanged from Questoins 2, 3), create a mapping for the "Punxsutawney Phil" column which changes the categories into numerical quantities. For example: 'No Record' can be 0, 'No Shadow' can be 1, 'Partial Shadow' can be 2, and 'Full Shadow' can be 3. You should create the mapping *and* apply it to the data set by adding a new column called "Shadow".

# %%
for i in range(0,131):
    if df.loc[i, 'Punxsutawney Phil'] == 'No Record':
        df.loc[i, 'Shadow'] = 0
    if df.loc[i, 'Punxsutawney Phil'] == 'No Shadow':
        df.loc[i, 'Shadow'] = 1
    if df.loc[i, 'Punxsutawney Phil'] == 'Partial Shadow':
        df.loc[i, 'Shadow'] = 2
    if df.loc[i, 'Punxsutawney Phil'] == 'Full Shadow':
        df.loc[i, 'Shadow'] = 3
df
# Out:
#      Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 0             0  1886         No Record                           NaN
# 1             1  1887       Full Shadow                           NaN
# 2             2  1888       Full Shadow                           NaN
# 3             3  1889         No Record                           NaN
# 4             4  1890         No Shadow                           NaN
# ..          ...   ...               ...                           ...
# 126         126  2012       Full Shadow                         37.51
# 127         127  2013         No Shadow                         34.77
# 128         128  2014       Full Shadow                         32.13
# 129         129  2015       Full Shadow                         32.99
# 130         130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 0                                         NaN     0.0
# 1                                         NaN     3.0
# 2                                         NaN     3.0
# 3                                         NaN     0.0
# 4                                         NaN     1.0
# ..                                        ...     ...
# 126                                      47.7     3.0
# 127                                      33.9     1.0
# 128                                      30.3     3.0
# 129                                      31.6     3.0
# 130                                      43.4     1.0
#
# [131 rows x 12 columns]

# %% [markdown]
# #### Question 5 - Remove the rows which have empty values in all of the quantitative columns. (Only 9 should be removed.)

# %%
drop = range(0, 9)
df = df.drop(df.index[drop])

# %%
df
# Out:
#      Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 9             9  1895         No Record                         26.60
# 10           10  1896         No Record                         35.04
# 11           11  1897         No Record                         33.39
# 12           12  1898       Full Shadow                         35.37
# 13           13  1899         No Record                         25.50
# ..          ...   ...               ...                           ...
# 126         126  2012       Full Shadow                         37.51
# 127         127  2013         No Shadow                         34.77
# 128         128  2014       Full Shadow                         32.13
# 129         129  2015       Full Shadow                         32.99
# 130         130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 9                                        15.6
# 10                                       22.2
# 11                                       23.6
# 12                                       24.8
# 13                                       18.1
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 9                                      21.9
# 10                                     33.5
# 11                                     34.7
# 12                                     33.3
# 13                                     22.2
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 9                                           17.0                      39.97
# 10                                          26.6                      38.03
# 11                                          27.9                      38.79
# 12                                          26.7                      41.05
# 13                                          20.0                      37.63
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 9                                     27.6
# 10                                    25.3
# 11                                    32.0
# 12                                    38.0
# 13                                    29.3
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 9                                   40.2
# 10                                  36.9
# 11                                  44.0
# 12                                  46.0
# 13                                  38.4
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 9                                        31.3     0.0
# 10                                       27.8     0.0
# 11                                       36.9     0.0
# 12                                       42.0     3.0
# 13                                       34.0     0.0
# ..                                        ...     ...
# 126                                      47.7     3.0
# 127                                      33.9     1.0
# 128                                      30.3     3.0
# 129                                      31.6     3.0
# 130                                      43.4     1.0
#
# [122 rows x 12 columns]

# %% [markdown]
# #### Question 6 - For the remaining rows which have no record (but the other columns *are* populated), determine an appropriate method for inputting the value for this column. Explain your reasoning, and show your work below (using pandas).

# %%
no_shadow = df.loc[df['Shadow'] == 1]
partial_shadow = df.loc[df['Shadow'] == 2]
full_shadow = df.loc[df['Shadow'] == 3]

stats = ['No Median', 'No Mean', 'No StD', 'Partial Median', 'Partial Mean', 'Partial StD', 'Full Median', 'Full Mean', 'Full StD']
d = {'Stats':stats}
stats_df = pd.DataFrame(d)

columns = ['Year', 'February Average Temperature', 'February Average Temperature (Northeast)', 'February Average Temperature (Midwest)', 'February Average Temperature (Pennsylvania)', 'March Average Temperature', 'March Average Temperature (Northeast)', 'March Average Temperature (Midwest)', 'March Average Temperature (Pennsylvania)']
for col in columns:
    stats_df.loc[0, col] = no_shadow[col].median()
    stats_df.loc[1, col] = no_shadow[col].mean()
    stats_df.loc[2, col] = no_shadow[col].std()
    stats_df.loc[3, col] = partial_shadow[col].median()
    stats_df.loc[4, col] = partial_shadow[col].mean()
    stats_df.loc[5, col] = partial_shadow[col].std()
    stats_df.loc[6, col] = full_shadow[col].median()
    stats_df.loc[7, col] = full_shadow[col].mean()
    stats_df.loc[8, col] = full_shadow[col].std()
stats_df
# Out:
#             Stats         Year  February Average Temperature  \
# 0       No Median  1990.000000                     35.550000
# 1         No Mean  1987.600000                     35.578000
# 2          No StD    23.042817                      2.189221
# 3  Partial Median  1942.000000                     30.740000
# 4    Partial Mean  1942.000000                     30.740000
# 5     Partial StD          NaN                           NaN
# 6     Full Median  1953.500000                     33.575000
# 7       Full Mean  1953.830000                     33.712500
# 8        Full StD    33.503522                      3.249446
#
#    February Average Temperature (Northeast)  \
# 0                                 24.100000
# 1                                 23.486667
# 2                                  4.767429
# 3                                 20.100000
# 4                                 20.100000
# 5                                       NaN
# 6                                 22.950000
# 7                                 22.727000
# 8                                  4.269551
#
#    February Average Temperature (Midwest)  \
# 0                               34.300000
# 1                               33.853333
# 2                                3.987994
# 3                               29.700000
# 4                               29.700000
# 5                                     NaN
# 6                               32.950000
# 7                               32.799000
# 8                                4.807664
#
#    February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                    27.400000                  42.800000
# 1                                    27.293333                  42.966000
# 2                                     4.871853                   2.918167
# 3                                    23.200000                  41.310000
# 4                                    23.200000                  41.310000
# 5                                          NaN                        NaN
# 6                                    26.950000                  41.810000
# 7                                    26.631000                  41.669800
# 8                                     4.453819                   2.941433
#
#    March Average Temperature (Northeast)  March Average Temperature (Midwest)  \
# 0                              33.000000                            43.500000
# 1                              32.966667                            43.026667
# 2                               3.003490                             4.148402
# 3                              35.700000                            44.100000
# 4                              35.700000                            44.100000
# 5                                    NaN                                  NaN
# 6                              32.400000                            42.700000
# 7                              32.369000                            42.620000
# 8                               3.994534                             4.649862
#
#    March Average Temperature (Pennsylvania)
# 0                                 37.200000
# 1                                 36.320000
# 2                                  3.550091
# 3                                 37.800000
# 4                                 37.800000
# 5                                       NaN
# 6                                 35.600000
# 7                                 35.947000
# 8                                  4.333810

# %%
print(no_shadow.shape[0])
print(partial_shadow.shape[0])
print(full_shadow.shape[0])
# Out:
# 15
# 1
# 100

# %%
df.loc[df['Shadow'] == 0]
# Out:
#     Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 9            9  1895         No Record                         26.60
# 10          10  1896         No Record                         35.04
# 11          11  1897         No Record                         33.39
# 13          13  1899         No Record                         25.50
# 16          16  1902         No Record                         31.46
# 57          57  1943         No Record                         36.28
#
#     February Average Temperature (Northeast)  \
# 9                                       15.6
# 10                                      22.2
# 11                                      23.6
# 13                                      18.1
# 16                                      20.1
# 57                                      23.9
#
#     February Average Temperature (Midwest)  \
# 9                                     21.9
# 10                                    33.5
# 11                                    34.7
# 13                                    22.2
# 16                                    23.6
# 57                                    35.4
#
#     February Average Temperature (Pennsylvania)  March Average Temperature  \
# 9                                          17.0                      39.97
# 10                                         26.6                      38.03
# 11                                         27.9                      38.79
# 13                                         20.0                      37.63
# 16                                         21.0                      41.58
# 57                                         27.6                      38.50
#
#     March Average Temperature (Northeast)  \
# 9                                    27.6
# 10                                   25.3
# 11                                   32.0
# 13                                   29.3
# 16                                   37.1
# 57                                   30.5
#
#     March Average Temperature (Midwest)  \
# 9                                  40.2
# 10                                 36.9
# 11                                 44.0
# 13                                 38.4
# 16                                 43.9
# 57                                 38.5
#
#     March Average Temperature (Pennsylvania)  Shadow
# 9                                       31.3     0.0
# 10                                      27.8     0.0
# 11                                      36.9     0.0
# 13                                      34.0     0.0
# 16                                      38.8     0.0
# 57                                      34.7     0.0

# %%
df.loc[9, 'Punxsutawney Phil'] = 'Full Shadow'
df.loc[9, 'Shadow'] = 3
df.loc[10, 'Punxsutawney Phil'] = 'Full Shadow'
df.loc[10, 'Shadow'] = 3
df.loc[11, 'Punxsutawney Phil'] = 'No Shadow'
df.loc[11, 'Shadow'] = 1
df.loc[13, 'Punxsutawney Phil'] = 'Full Shadow'
df.loc[13, 'Shadow'] = 3
df.loc[16, 'Punxsutawney Phil'] = 'Partial Shadow'
df.loc[16, 'Shadow'] = 2
df.loc[57, 'Punxsutawney Phil'] = 'Full Shadow'
df.loc[57, 'Shadow'] = 3

# %%
df
# Out:
#      Unnamed: 0  Year Punxsutawney Phil  February Average Temperature  \
# 9             9  1895       Full Shadow                         26.60
# 10           10  1896       Full Shadow                         35.04
# 11           11  1897         No Shadow                         33.39
# 12           12  1898       Full Shadow                         35.37
# 13           13  1899       Full Shadow                         25.50
# ..          ...   ...               ...                           ...
# 126         126  2012       Full Shadow                         37.51
# 127         127  2013         No Shadow                         34.77
# 128         128  2014       Full Shadow                         32.13
# 129         129  2015       Full Shadow                         32.99
# 130         130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 9                                        15.6
# 10                                       22.2
# 11                                       23.6
# 12                                       24.8
# 13                                       18.1
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 9                                      21.9
# 10                                     33.5
# 11                                     34.7
# 12                                     33.3
# 13                                     22.2
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 9                                           17.0                      39.97
# 10                                          26.6                      38.03
# 11                                          27.9                      38.79
# 12                                          26.7                      41.05
# 13                                          20.0                      37.63
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 9                                     27.6
# 10                                    25.3
# 11                                    32.0
# 12                                    38.0
# 13                                    29.3
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 9                                   40.2
# 10                                  36.9
# 11                                  44.0
# 12                                  46.0
# 13                                  38.4
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 9                                        31.3     3.0
# 10                                       27.8     3.0
# 11                                       36.9     1.0
# 12                                       42.0     3.0
# 13                                       34.0     3.0
# ..                                        ...     ...
# 126                                      47.7     3.0
# 127                                      33.9     1.0
# 128                                      30.3     3.0
# 129                                      31.6     3.0
# 130                                      43.4     1.0
#
# [122 rows x 12 columns]

# %% [markdown]
# The method I used in this question was comparing the temperature values for each year that had 'No Record' with the median, mean, and standard deviation of the temperature values for the different possible values of 'Shadow' individually. I also took into account the frequency of each value as 'Partial Shadow' only occured once, 'No Shadow' occured 15 times, and 'Full Shadow' occured 100 times. I compared each of the 8 temperature values and saw which of the 3 types it matched with the most.

# %% [markdown]
# #### Question 7 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the independent variables X? Why?
#
# #### Use pandas to assign a variable X to be all of the rows of the data set with the column(s) that represent the independent variables.

# %% [markdown]
# 'Year', 'February Average Temperature', 'February Average Temperature (Northeast)', 'February Average Temperature (Midwest)', 'February Average Temperature (Pennsylvania)', 'March Average Temperature', 'March Average Temperature (Northeast)', 'March Average Temperature (Midwest)', and 'March Average Temperature (Pennsylvania)' should all be independent variables as they can all be used in order to predict the shadow for a given year and do not store the actual information about the shadow themselves.

# %%
X = df
X = X.drop(['Unnamed: 0', 'Punxsutawney Phil', 'Shadow'], axis = 1)

# %%
X
# Out:
#      Year  February Average Temperature  \
# 9    1895                         26.60
# 10   1896                         35.04
# 11   1897                         33.39
# 12   1898                         35.37
# 13   1899                         25.50
# ..    ...                           ...
# 126  2012                         37.51
# 127  2013                         34.77
# 128  2014                         32.13
# 129  2015                         32.99
# 130  2016                         39.47
#
#      February Average Temperature (Northeast)  \
# 9                                        15.6
# 10                                       22.2
# 11                                       23.6
# 12                                       24.8
# 13                                       18.1
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 9                                      21.9
# 10                                     33.5
# 11                                     34.7
# 12                                     33.3
# 13                                     22.2
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 9                                           17.0                      39.97
# 10                                          26.6                      38.03
# 11                                          27.9                      38.79
# 12                                          26.7                      41.05
# 13                                          20.0                      37.63
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 9                                     27.6
# 10                                    25.3
# 11                                    32.0
# 12                                    38.0
# 13                                    29.3
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 9                                   40.2
# 10                                  36.9
# 11                                  44.0
# 12                                  46.0
# 13                                  38.4
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)
# 9                                        31.3
# 10                                       27.8
# 11                                       36.9
# 12                                       42.0
# 13                                       34.0
# ..                                        ...
# 126                                      47.7
# 127                                      33.9
# 128                                      30.3
# 129                                      31.6
# 130                                      43.4
#
# [122 rows x 9 columns]

# %% [markdown]
# #### Question 8 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the dependent variables Y? Why?
#
# #### Use pandas to assign a variable Y to be all of the rows of the data set with the column(s) that represent the dependent variables.

# %% [markdown]
# 'Punxsutawney Phil' and 'Shadow' should be the dependent variable as they store the type of shadow which is the information that we are trying to predict.

# %%
Y = df
Y = Y.drop(['Unnamed: 0', 'Year', 'February Average Temperature', 'February Average Temperature (Northeast)', 'February Average Temperature (Midwest)', 'February Average Temperature (Pennsylvania)', 'March Average Temperature', 'March Average Temperature (Northeast)', 'March Average Temperature (Midwest)', 'March Average Temperature (Pennsylvania)'], axis = 1)

# %%
Y
# Out:
#     Punxsutawney Phil  Shadow
# 9         Full Shadow     3.0
# 10        Full Shadow     3.0
# 11          No Shadow     1.0
# 12        Full Shadow     3.0
# 13        Full Shadow     3.0
# ..                ...     ...
# 126       Full Shadow     3.0
# 127         No Shadow     1.0
# 128       Full Shadow     3.0
# 129       Full Shadow     3.0
# 130         No Shadow     1.0
#
# [122 rows x 2 columns]

# %% [markdown]
# #### Question 9 - Using the train_test_split function from the sklearn module, use a 70/30 split validation to split the data set into train and test. If you follow the example at the following link: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# Note: It's common practice to use the following variable names for unpacking the result:
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=(YOUR VALUE))
#
# sklearn will create a proper split where the following statements hold true:
# X_train is your train set independent variables
# Y_train is your train set dependent variables
# X_test is your test set independent variables
# Y_test is your test set dependent variables

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7)

# %%
X_train
# Out:
#      Year  February Average Temperature  \
# 32   1918                         33.82
# 103  1989                         29.17
# 25   1911                         33.66
# 116  2002                         36.39
# 96   1982                         32.59
# ..    ...                           ...
# 38   1924                         35.19
# 99   1985                         30.87
# 70   1956                         32.27
# 75   1961                         37.42
# 61   1947                         31.41
#
#      February Average Temperature (Northeast)  \
# 32                                       19.8
# 103                                      23.0
# 25                                       21.4
# 116                                      29.7
# 96                                       22.9
# ..                                        ...
# 38                                       18.3
# 99                                       24.8
# 70                                       25.6
# 75                                       24.6
# 61                                       20.5
#
#      February Average Temperature (Midwest)  \
# 32                                     34.1
# 103                                    28.6
# 25                                     37.5
# 116                                    36.8
# 96                                     30.4
# ..                                      ...
# 38                                     31.7
# 99                                     28.4
# 70                                     36.1
# 75                                     37.3
# 61                                     25.7
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 32                                          25.7                      45.75
# 103                                         27.1                      42.67
# 25                                          28.5                      44.02
# 116                                         33.9                      39.54
# 96                                          26.9                      42.03
# ..                                           ...                        ...
# 38                                          23.9                      37.18
# 99                                          27.1                      43.48
# 70                                          29.8                      40.75
# 75                                          28.9                      43.47
# 61                                          21.7                      38.75
#
#      March Average Temperature (Northeast)  \
# 32                                    32.9
# 103                                   31.8
# 25                                    28.4
# 116                                   34.7
# 96                                    31.5
# ..                                     ...
# 38                                    31.3
# 99                                    34.5
# 70                                    27.9
# 75                                    32.6
# 61                                    29.7
#
#      March Average Temperature (Midwest)  \
# 32                                  48.2
# 103                                 44.0
# 25                                  42.9
# 116                                 41.5
# 96                                  43.5
# ..                                   ...
# 38                                  37.5
# 99                                  46.3
# 70                                  42.1
# 75                                  45.1
# 61                                  34.8
#
#      March Average Temperature (Pennsylvania)
# 32                                       39.3
# 103                                      36.7
# 25                                       32.8
# 116                                      38.2
# 96                                       34.9
# ..                                        ...
# 38                                       33.5
# 99                                       38.3
# 70                                       32.9
# 75                                       37.1
# 61                                       30.3
#
# [85 rows x 9 columns]

# %%
Y_train
# Out:
#     Punxsutawney Phil  Shadow
# 32        Full Shadow     3.0
# 103       Full Shadow     3.0
# 25        Full Shadow     3.0
# 116       Full Shadow     3.0
# 96        Full Shadow     3.0
# ..                ...     ...
# 38        Full Shadow     3.0
# 99        Full Shadow     3.0
# 70        Full Shadow     3.0
# 75        Full Shadow     3.0
# 61        Full Shadow     3.0
#
# [85 rows x 2 columns]

# %%
X_test
# Out:
#      Year  February Average Temperature  \
# 85   1971                         33.48
# 15   1901                         29.86
# 106  1992                         39.70
# 110  1996                         35.69
# 104  1990                         36.70
# 81   1967                         32.88
# 26   1912                         31.08
# 69   1955                         31.05
# 59   1945                         35.28
# 41   1927                         37.90
# 115  2001                         33.98
# 17   1903                         28.42
# 18   1904                         31.59
# 72   1958                         31.98
# 51   1937                         31.73
# 124  2010                         31.80
# 19   1905                         26.94
# 105  1991                         39.81
# 126  2012                         37.51
# 39   1925                         38.30
# 95   1981                         36.59
# 58   1944                         34.50
# 100  1986                         35.85
# 76   1962                         34.92
# 107  1993                         31.14
# 11   1897                         33.39
# 48   1934                         34.32
# 83   1969                         32.81
# 121  2007                         32.41
# 62   1948                         31.62
# 36   1922                         31.95
# 31   1917                         30.09
# 97   1983                         36.86
# 45   1931                         37.94
# 114  2000                         39.78
# 14   1900                         30.76
# 117  2003                         32.79
#
#      February Average Temperature (Northeast)  \
# 85                                       23.9
# 15                                       16.0
# 106                                      25.7
# 110                                      23.6
# 104                                      28.0
# 81                                       18.2
# 26                                       18.6
# 69                                       24.2
# 59                                       23.6
# 41                                       26.2
# 115                                      26.0
# 17                                       24.5
# 18                                       15.0
# 72                                       17.9
# 51                                       26.3
# 124                                      25.9
# 19                                       15.2
# 105                                      28.7
# 126                                      30.6
# 39                                       29.2
# 95                                       30.3
# 58                                       22.4
# 100                                      22.3
# 76                                       19.8
# 107                                      17.5
# 11                                       23.6
# 48                                       10.4
# 83                                       23.7
# 121                                      18.0
# 62                                       19.7
# 36                                       24.2
# 31                                       17.8
# 97                                       26.2
# 45                                       24.2
# 114                                      27.2
# 14                                       21.4
# 117                                      20.0
#
#      February Average Temperature (Midwest)  \
# 85                                     31.8
# 15                                     26.2
# 106                                    39.5
# 110                                    33.4
# 104                                    39.9
# 81                                     29.1
# 26                                     25.8
# 69                                     33.4
# 59                                     33.9
# 41                                     40.4
# 115                                    36.1
# 17                                     31.3
# 18                                     28.2
# 72                                     24.5
# 51                                     32.2
# 124                                    28.2
# 19                                     22.2
# 105                                    37.4
# 126                                    38.6
# 39                                     38.7
# 95                                     34.1
# 58                                     36.3
# 100                                    34.3
# 76                                     34.8
# 107                                    30.5
# 11                                     34.7
# 48                                     27.2
# 83                                     33.0
# 121                                    26.1
# 62                                     32.9
# 36                                     35.7
# 31                                     29.1
# 97                                     35.9
# 45                                     38.0
# 114                                    40.1
# 14                                     27.5
# 117                                    30.2
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 85                                          27.5                      39.65
# 15                                          18.9                      40.71
# 106                                         30.9                      44.71
# 110                                         27.0                      39.02
# 104                                         33.9                      44.74
# 81                                          22.6                      43.63
# 26                                          21.1                      35.76
# 69                                          27.3                      40.06
# 59                                          27.1                      45.54
# 41                                          32.0                      42.26
# 115                                         31.5                      41.49
# 17                                          28.0                      42.21
# 18                                          19.2                      41.76
# 72                                          20.4                      37.67
# 51                                          28.5                      38.84
# 124                                         25.8                      43.57
# 19                                          18.1                      45.12
# 105                                         32.4                      43.32
# 126                                         34.3                      50.41
# 39                                          32.8                      44.24
# 95                                          30.7                      42.85
# 58                                          27.5                      38.50
# 100                                         26.7                      46.18
# 76                                          25.4                      37.90
# 107                                         23.5                      41.79
# 11                                          27.9                      38.79
# 48                                          15.2                      42.78
# 83                                          26.7                      36.03
# 121                                         20.1                      47.66
# 62                                          25.6                      38.71
# 36                                          30.1                      40.42
# 31                                          23.0                      38.35
# 97                                          29.8                      42.40
# 45                                          29.0                      39.42
# 114                                         31.6                      46.04
# 14                                          24.1                      41.27
# 117                                         23.8                      43.30
#
#      March Average Temperature (Northeast)  \
# 85                                    29.9
# 15                                    30.8
# 106                                   30.0
# 110                                   29.7
# 104                                   35.7
# 81                                    29.1
# 26                                    27.7
# 69                                    32.3
# 59                                    41.6
# 41                                    35.2
# 115                                   30.2
# 17                                    40.4
# 18                                    29.8
# 72                                    33.3
# 51                                    27.6
# 124                                   39.6
# 19                                    31.4
# 105                                   36.1
# 126                                   43.4
# 39                                    35.5
# 95                                    33.0
# 58                                    28.9
# 100                                   34.7
# 76                                    32.7
# 107                                   29.8
# 11                                    32.0
# 48                                    29.2
# 83                                    30.1
# 121                                   32.7
# 62                                    32.7
# 36                                    33.8
# 31                                    31.2
# 97                                    35.7
# 45                                    32.9
# 114                                   39.1
# 14                                    26.0
# 117                                   32.9
#
#      March Average Temperature (Midwest)  \
# 85                                  38.9
# 15                                  41.9
# 106                                 44.0
# 110                                 37.2
# 104                                 46.6
# 81                                  45.6
# 26                                  35.2
# 69                                  43.1
# 59                                  51.9
# 41                                  44.6
# 115                                 39.3
# 17                                  47.7
# 18                                  42.8
# 72                                  37.3
# 51                                  38.2
# 124                                 44.6
# 19                                  47.2
# 105                                 46.1
# 126                                 56.3
# 39                                  45.0
# 95                                  41.7
# 58                                  39.8
# 100                                 45.0
# 76                                  38.6
# 107                                 39.5
# 11                                  44.0
# 48                                  38.8
# 83                                  36.2
# 121                                 50.1
# 62                                  43.4
# 36                                  44.1
# 31                                  42.6
# 97                                  43.5
# 45                                  37.7
# 114                                 47.7
# 14                                  37.9
# 117                                 44.8
#
#      March Average Temperature (Pennsylvania)
# 85                                       32.5
# 15                                       35.1
# 106                                      34.5
# 110                                      31.8
# 104                                      40.2
# 81                                       34.4
# 26                                       31.5
# 69                                       37.2
# 59                                       46.2
# 41                                       39.2
# 115                                      33.3
# 17                                       44.5
# 18                                       34.0
# 72                                       33.7
# 51                                       31.4
# 124                                      42.0
# 19                                       36.9
# 105                                      39.5
# 126                                      47.7
# 39                                       38.1
# 95                                       34.1
# 58                                       32.7
# 100                                      38.0
# 76                                       34.2
# 107                                      32.8
# 11                                       36.9
# 48                                       32.1
# 83                                       32.7
# 121                                      37.4
# 62                                       38.3
# 36                                       37.1
# 31                                       35.4
# 97                                       38.7
# 45                                       33.7
# 114                                      42.6
# 14                                       29.3
# 117                                      37.2

# %%
Y_test
# Out:
#     Punxsutawney Phil  Shadow
# 85        Full Shadow     3.0
# 15        Full Shadow     3.0
# 106       Full Shadow     3.0
# 110       Full Shadow     3.0
# 104         No Shadow     1.0
# 81        Full Shadow     3.0
# 26        Full Shadow     3.0
# 69        Full Shadow     3.0
# 59        Full Shadow     3.0
# 41        Full Shadow     3.0
# 115       Full Shadow     3.0
# 17        Full Shadow     3.0
# 18        Full Shadow     3.0
# 72        Full Shadow     3.0
# 51        Full Shadow     3.0
# 124       Full Shadow     3.0
# 19        Full Shadow     3.0
# 105       Full Shadow     3.0
# 126       Full Shadow     3.0
# 39        Full Shadow     3.0
# 95        Full Shadow     3.0
# 58        Full Shadow     3.0
# 100         No Shadow     1.0
# 76        Full Shadow     3.0
# 107       Full Shadow     3.0
# 11          No Shadow     1.0
# 48          No Shadow     1.0
# 83        Full Shadow     3.0
# 121         No Shadow     1.0
# 62        Full Shadow     3.0
# 36        Full Shadow     3.0
# 31        Full Shadow     3.0
# 97          No Shadow     1.0
# 45        Full Shadow     3.0
# 114       Full Shadow     3.0
# 14        Full Shadow     3.0
# 117       Full Shadow     3.0

# %% [markdown]
# #### Question 10 - Should the number of rows in X_train == number of rows in Y_train? Also, should the number of rows in X_test == Y_test? Why or why not? Validate your answer with code below:

# %% [markdown]
# The number of rows in X_train should equal the number of rows in Y_train and the number of rows in X_test should equal the number of rows in Y_test. This is because both of the train datasets have to refer to all the same rows in order to accurately train the machine learning program. The same goes for the test datasets in order to accurate test the program. This is also why the train_test_split function symmetrically splits the rows in X and Y.

# %%
print(X_train.shape[0] == Y_train.shape[0])
# Out:
# True

# %%
print(X_test.shape[0] == Y_test.shape[0])
# Out:
# True
